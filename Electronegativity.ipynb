# %%
import numpy as np
lantanoids=np.linspace(1.0,1.2,15)
electronegativity=[2.1,1.0,1.5,2.0,2.5,3.0,3.5,4.0,0.9,1.2,1.5,1.8,2.1,2.5,3.0,0.8,1.0,1.3,1.5,1.6,1.6,1.5,1.8,1.9,1.9,1.9,1.6,1.6,1.8,2.0,2.4,2.8,0.8,1.0,1.2,1.4,1.6,1.8,1.9,2.2,2.2,2.2,1.9,1.7,1.7,1.8,1.9,2.1,2.5,0.7,0.9]
print(electronegativity)
electronegativity=np.array(electronegativity)
electronegativity=np.concatenate((electronegativity,lantanoids))
electronegativityHf_U=[1.3,1.5,1.7,1.9,2.2,2.2,2.2,2.4,1.9,1.8,1.9,1.9,2.0,2.2,0.7,0.9,1.1,1.3,1.4,1.4]
Np_NO=np.linspace(1.4,1.3,10)
electronegativityHf_U=np.array(electronegativityHf_U)
electronegativity=np.concatenate((electronegativity,electronegativityHf_U))
electronegativity=np.concatenate((electronegativity,Np_NO))
# Out:
# [2.1, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0, 0.9, 1.2, 1.5, 1.8, 2.1, 2.5, 3.0, 0.8, 1.0, 1.3, 1.5, 1.6, 1.6, 1.5, 1.8, 1.9, 1.9, 1.9, 1.6, 1.6, 1.8, 2.0, 2.4, 2.8, 0.8, 1.0, 1.2, 1.4, 1.6, 1.8, 1.9, 2.2, 2.2, 2.2, 1.9, 1.7, 1.7, 1.8, 1.9, 2.1, 2.5, 0.7, 0.9]

# %%
electronegativity
Z=np.arange(1,2)
Z=np.concatenate((Z,np.arange(3,10)))
Z=np.concatenate((Z,np.arange(11,18)))
Z=np.concatenate((Z,np.arange(19,36)))
Z=np.concatenate((Z,np.arange(37,54)))
Z=np.concatenate((Z,np.arange(55,86)))
Z=np.concatenate((Z,np.arange(87,103)))
np.shape(Z)
# Out:
# (96,)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Z,electronegativity,color="black")
plt.scatter(Z,electronegativity,s=10,color="black")
plt.xlabel("Atomic number")
plt.ylabel("Electronegativity")
plt.title("Electronegativity")
# Out:
# Text(0.5, 1.0, 'Electronegativity')

# %%
plt.scatter(Z,electronegativity,s=20,color="black")
plt.xlabel("Atomic number")
plt.ylabel("Electronegativity")
plt.title("Electronegativity")
# Out:
# Text(0.5, 1.0, 'Electronegativity')

# %%
plt.scatter(Z,electronegativity,s=10,color="black")
plt.xlabel("Atomic number")
plt.ylabel("Electronegativity")
plt.title("Electronegativity Periodity")
plt.plot(Z[1:8],electronegativity[1:8],color="black")
plt.text(Z[7],electronegativity[7],Z[7])
plt.plot(Z[8:15],electronegativity[8:15],color="black")
plt.text(Z[14],electronegativity[14],Z[14])
plt.plot(Z[15:32],electronegativity[15:32],color="black")
plt.text(Z[31],electronegativity[31],Z[31])
plt.plot(Z[32:49],electronegativity[32:49],color="black")
plt.text(Z[48],electronegativity[48],Z[48])
plt.plot(Z[49:80],electronegativity[49:80],color="black")
plt.text(Z[79],electronegativity[79],Z[79])
plt.plot(Z[80:85],electronegativity[80:85],color="black")
plt.plot(Z[85:],electronegativity[85:],color="black")

# %%
plt.scatter(Z,electronegativity,s=10,color="black")
plt.xlabel("Atomic number")
plt.ylabel("Electronegativity")
plt.title("Electronegativity Periodity")
plt.plot(Z[1:8],electronegativity[1:8],color="black")
plt.text(Z[7],electronegativity[7],"F",color="purple")
plt.plot(Z[8:15],electronegativity[8:15],color="black")
plt.text(Z[14],electronegativity[14],"Cl",color="purple")
plt.plot(Z[15:32],electronegativity[15:32],color="black")
plt.text(Z[31],electronegativity[31],"Br",color="purple")
plt.plot(Z[32:49],electronegativity[32:49],color="black")
plt.text(Z[48],electronegativity[48],"I",color="purple")
plt.plot(Z[49:80],electronegativity[49:80],color="black")
plt.text(Z[79],electronegativity[79],"At",color="purple")
plt.plot(Z[80:85],electronegativity[80:85],color="black")
plt.plot(Z[85:],electronegativity[85:],color="black")

# %% [markdown]
# From this we can see how electronegativity is periodic, with the pattern repeating in every period of the periodic table.
